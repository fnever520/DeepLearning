# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
#from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# ## Downloading Data

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
    print(_)
    print(filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# ## Converting data to a string

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# ## Building the Vocabulary (Dictionaries)

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# ## Generating batches of data
#
# Unlike data in skip-gram, here data is of following sizes
# * batch: [batch_size, context_window size - 1] # words found in the context
# * labels: [batch_size, 1] # target word (word to be predicted)

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index

    span = 2 * skip_window + 1 # [ skip_window target skip_window ]

    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side

    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)

    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself

        # do this num_skips (2 times)
        # do this (1 time)

        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels



for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# ## Running Embedding Learning

# %%
num_steps = 100000

if __name__ == '__main__':
    batch_size = 128
    embedding_size = 128 # Dimension of the embedding vector.
    skip_window = 1 # How many words to consider left and right.
    num_skips = 2 # How many times to reuse an input to generate a label.
    # We pick a random validation set to sample nearest neighbors. here we limit the
    # validation samples to the words that have a low numeric ID, which by
    # construction are also the most frequent.
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100 # Only pick dev samples in the head of the distribution.
    # pick 16 samples from 100
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
    num_sampled = 64 # Number of negative examples to sample.

    graph = tf.Graph()

    with graph.as_default(), tf.device('/cpu:0'):

        # Input data.
        train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

        # Variables.
        # embedding, vector for each word in the vocabulary
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
        softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Averaging embeddings accross the full context into a single embedding layer
        context_embeddings = []
        for i in range(2*skip_window):
            context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))
            
        avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False)

        # Compute the softmax loss, using a sample of the negative labels each time.
        # inputs are embeddings of the train words
        # with this loss we optimize weights, biases, embeddings

        loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

        # Optimizer.
        optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

        # Compute the similarity between minibatch examples and all embeddings.
        # We use the cosine distance:
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

    with tf.Session(graph=graph) as session:
        tf.global_variables_initializer().run()
        print('Initialized')
        average_loss = 0
        for step in range(num_steps):
            batch_data, batch_labels = generate_batch(batch_size, skip_window)
            feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
            _, l = session.run([optimizer, loss], feed_dict=feed_dict)
            average_loss += l
            if step % 2000 == 0:
                if step > 0:
                    average_loss = average_loss / 2000
                    # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
        final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-6-3160d5537020>:39: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\nn_impl.py:1124: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From <ipython-input-6-3160d5537020>:53: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Initialized
# Average loss at step 0: 8.007677
# Nearest to not: medications, polio, neoconservative, kwashiorkor, astatine, vadim, progesterone, madhu,
# Nearest to that: fuelling, fulani, literatures, autobiographical, vhdl, gtb, iban, chapter,
# Nearest to there: metallurgy, carloman, sediments, lifeless, porous, edelman, vfa, christy,
# Nearest to to: drachmae, amigas, uninhabited, mickey, ferris, rsfsr, fuchs, transcribing,
# Nearest to see: colspan, gmc, deploy, xxvii, ibrahim, anabaptism, trackball, robotech,
# Nearest to while: aan, parsed, inborn, intentions, lengthwise, carmelite, palms, periodically,
# Nearest to as: publius, eocene, dimers, planets, mazzola, arnaz, authentically, anthroposophy,
# Nearest to used: fanbase, suspected, gms, amp, theoretic, establish, scramble, sweets,
# Nearest to proposed: beatle, errico, dangerous, maternal, measurable, farming, anc, safl,
# Nearest to square: allahabad, transitional, viterbo, clarion, axe, quark, opium, canc,
# Nearest to freedom: enforce, tetrahedral, brock, occurred, bretton, novelty, cupboard, enthalpy,
# Nearest to heavy: naval, kidder, bentheim, specialty, gia, intercept, microphone, preacher,
# Nearest to active: radically, misogynist, simplifying, tours, quarterback, tones, borghese, acquires,
# Nearest to arts: nasal, plato, tod, abiotic, krav, alda, adiabats, flemish,
# Nearest to construction: buzzard, rin, mboxx, extremity, stringing, regretted, mma, food,
# Nearest to additional: world, bosnia, tompkins, init, mol, damping, crematorium, shoshone,
# Average loss at step 2000: 4.034646
# Average loss at step 4000: 3.510434
# Average loss at step 6000: 3.343951
# Average loss at step 8000: 3.193095
# Average loss at step 10000: 3.149714
# Nearest to not: also, wassily, stretching, sometimes, elongated, kobayashi, surgically, hemorrhagic,
# Nearest to that: which, riga, chapter, metrical, this, fuelling, kumar, what,
# Nearest to there: they, lockheed, it, he, olympian, burnt, combats, metallurgy,
# Nearest to to: ferris, would, can, transcribing, dragon, not, hander, escher,
# Nearest to see: anabaptism, asses, subdisciplines, catalans, tabulation, resorts, haul, ranges,
# Nearest to while: inborn, rashid, targum, intentions, viewed, deceived, outre, magazine,
# Nearest to as: fiorentina, dimers, eocene, claude, joni, dilation, mazzola, when,
# Nearest to used: known, spielberg, eldr, held, fetishes, daring, ghent, gms,
# Nearest to proposed: beatle, errico, maternal, measurable, know, safl, dangerous, anc,
# Nearest to square: allahabad, clarion, viterbo, axe, transitional, quark, opium, freer,
# Nearest to freedom: tetrahedral, enforce, brock, bretton, enthalpy, dx, occurred, repellent,
# Nearest to heavy: naval, specialty, kidder, gia, bentheim, preacher, microphone, intercept,
# Nearest to active: radically, simplifying, tours, quarterback, tones, misogynist, acquires, collision,
# Nearest to arts: nasal, tod, plato, memory, abiotic, flemish, krav, alda,
# Nearest to construction: buzzard, stringing, rin, extremity, narcotic, regretted, discovers, kelp,
# Nearest to additional: tompkins, bosnia, init, mol, shoshone, loco, fatty, platonism,
# Average loss at step 12000: 3.171640
# Average loss at step 14000: 3.131642
# Average loss at step 16000: 3.150707
# Average loss at step 18000: 3.099537
# Average loss at step 20000: 2.992600
# Nearest to not: sometimes, always, generally, stretching, wassily, also, calculate, capricious,
# Nearest to that: which, this, what, metrical, riga, steamship, where, however,
# Nearest to there: they, it, he, combats, lockheed, anguish, we, sinusoidal,
# Nearest to to: ferris, would, not, will, transcribing, can, installing, utopia,
# Nearest to see: asses, haul, takes, tabulation, resorts, viper, subdisciplines, catalans,
# Nearest to while: although, targum, magazine, rashid, inborn, outre, toward, ambiguously,
# Nearest to as: fiorentina, dimers, dartmouth, cloaca, preterite, mystics, transferable, when,
# Nearest to used: known, held, found, referred, spielberg, available, fetishes, eldr,
# Nearest to proposed: beatle, errico, know, maternal, measurable, cytochrome, dangerous, anc,
# Nearest to square: allahabad, clarion, viterbo, transitional, quark, axe, freer, leger,
# Nearest to freedom: tetrahedral, repellent, enforce, bretton, enthalpy, knopf, plywood, dx,
# Nearest to heavy: naval, specialty, bentheim, kidder, gia, preacher, oup, microphone,
# Nearest to active: radically, simplifying, playing, collision, tours, acquires, tones, misogynist,
# Nearest to arts: nasal, tod, memory, plato, flemish, krav, alda, discounted,
# Nearest to construction: buzzard, stringing, narcotic, rin, discovers, adamant, extremity, athabasca,
# Nearest to additional: tompkins, embodiment, shoshone, loco, mol, lowry, australians, init,
# Average loss at step 22000: 3.054675
# Average loss at step 24000: 3.022988
# Average loss at step 26000: 2.987175
# Average loss at step 28000: 3.017309
# Average loss at step 30000: 2.991516
# Nearest to not: always, generally, sometimes, never, stretching, wassily, typically, calculate,
# Nearest to that: which, this, what, however, where, riga, antidisestablishmentarianism, steamship,
# Nearest to there: they, it, he, combats, anguish, we, kames, heiland,
# Nearest to to: ferris, would, will, might, could, can, should, installing,
# Nearest to see: asses, interjections, called, resorts, haul, irresponsibility, tabulation, takes,
# Nearest to while: although, after, targum, toward, magazine, inborn, rashid, across,
# Nearest to as: cloaca, preterite, fiorentina, demotic, dartmouth, meticulous, transferable, dimers,
# Nearest to used: known, referred, held, seen, found, available, sadr, released,
# Nearest to proposed: beatle, errico, know, maternal, cytochrome, fis, dangerous, anc,
# Nearest to square: allahabad, clarion, quark, viterbo, transitional, axe, freer, five,
# Nearest to freedom: tetrahedral, repellent, bretton, enforce, knopf, enthalpy, plywood, bdsm,
# Nearest to heavy: naval, specialty, kidder, bentheim, gia, oup, preacher, cried,
# Nearest to active: radically, simplifying, collision, acquires, tours, playing, tones, quarterback,
# Nearest to arts: nasal, memory, tod, plato, discounted, flemish, art, krav,
# Nearest to construction: buzzard, stringing, ethics, adamant, majority, extremity, athabasca, narcotic,
# Nearest to additional: tompkins, embodiment, loco, shoshone, lowry, mol, racist, australians,
# Average loss at step 32000: 2.839718
# Average loss at step 34000: 2.949797
# Average loss at step 36000: 2.935086
# Average loss at step 38000: 2.933730
# Average loss at step 40000: 2.917327
# Nearest to not: always, generally, never, actually, wassily, sometimes, typically, calculate,
# Nearest to that: which, however, what, mormonism, tackled, where, this, kumar,
# Nearest to there: they, it, he, we, these, combats, dioxide, sinusoidal,
# Nearest to to: ferris, might, will, would, should, can, satie, may,
# Nearest to see: interjections, asses, haul, tabulation, sasha, refers, geometric, include,
# Nearest to while: although, toward, but, though, after, targum, before, across,
# Nearest to as: preterite, dartmouth, fiorentina, cloaca, demotic, when, joni, idb,
# Nearest to used: known, referred, available, found, involved, seen, held, responsible,
# Nearest to proposed: beatle, fis, errico, maternal, anc, dangerous, cytochrome, distributors,
# Nearest to square: allahabad, clarion, viterbo, quark, transitional, axe, freer, instructional,
# Nearest to freedom: repellent, tetrahedral, bretton, knopf, enthalpy, occurred, satisfying, enforce,
# Nearest to heavy: specialty, naval, kidder, bentheim, oup, cried, preacher, gia,
# Nearest to active: radically, simplifying, collision, container, pete, tones, acquires, quarterback,
# Nearest to arts: nasal, art, memory, discounted, sociology, flemish, tod, plato,
# Nearest to construction: buzzard, majority, ethics, adamant, stringing, prophase, discovers, athabasca,
# Nearest to additional: tompkins, embodiment, loco, lowry, mol, shoshone, jolla, racist,
# Average loss at step 42000: 2.942529
# Average loss at step 44000: 2.943499
# Average loss at step 46000: 2.902979
# Average loss at step 48000: 2.870045
# Average loss at step 50000: 2.843293
# Nearest to not: always, actually, never, generally, calculate, wassily, still, typically,
# Nearest to that: which, what, however, this, where, riga, steamship, mormonism,
# Nearest to there: they, it, he, we, leclerc, malone, these, bats,
# Nearest to to: ferris, might, should, will, towards, satie, would, must,
# Nearest to see: interjections, sasha, aur, refers, asses, consider, haul, tabulation,
# Nearest to while: although, after, toward, but, though, when, before, prosaic,
# Nearest to as: cloaca, dartmouth, fiorentina, dimers, joni, klansmen, demotic, preterite,
# Nearest to used: known, referred, available, involved, found, held, necessary, required,
# Nearest to proposed: errico, fis, maternal, beatle, dangerous, distributors, derg, anc,
# Nearest to square: allahabad, viterbo, clarion, quark, transitional, freer, instructional, axe,
# Nearest to freedom: repellent, tetrahedral, bretton, knopf, classifies, plurals, enthalpy, satisfying,
# Nearest to heavy: specialty, bentheim, kidder, oup, naval, gautama, cried, preacher,
# Nearest to active: radically, collision, simplifying, container, pete, tones, venturing, acquires,
# Nearest to arts: nasal, art, memory, discounted, sociology, flemish, tod, dal,
# Nearest to construction: buzzard, ethics, majority, adamant, stringing, scientific, prophase, athabasca,
# Nearest to additional: tompkins, embodiment, mol, loco, lowry, jolla, odd, shoshone,
# Average loss at step 52000: 2.883802
# Average loss at step 54000: 2.861728
# Average loss at step 56000: 2.855443
# Average loss at step 58000: 2.763908
# Average loss at step 60000: 2.825412
# Nearest to not: never, actually, always, calculate, generally, typically, wassily, t,
# Nearest to that: which, however, what, mormonism, riga, antidisestablishmentarianism, about, mixtures,
# Nearest to there: they, it, he, we, she, leclerc, heiland, malone,
# Nearest to to: ferris, might, should, will, towards, would, cannot, could,
# Nearest to see: refers, consider, interjections, sasha, include, aur, goldoni, geometric,
# Nearest to while: although, when, though, after, before, toward, but, and,
# Nearest to as: cloaca, preterite, fiorentina, demotic, diocesan, because, dimers, meticulous,
# Nearest to used: known, referred, involved, required, considered, available, seen, opposed,
# Nearest to proposed: led, fis, explained, errico, crept, created, proved, beatle,
# Nearest to square: allahabad, viterbo, transitional, clarion, quark, veeck, freer, axe,
# Nearest to freedom: repellent, tetrahedral, classifies, bretton, knopf, plurals, beatification, enthalpy,
# Nearest to heavy: specialty, oup, kidder, bentheim, gautama, cried, naval, preacher,
# Nearest to active: radically, collision, important, hallstatt, simplifying, container, open, quarterback,
# Nearest to arts: nasal, art, memory, discounted, sociology, flemish, jewel, dal,
# Nearest to construction: buzzard, majority, ethics, adamant, vital, scientific, stringing, prophase,
# Nearest to additional: tompkins, embodiment, odd, mol, jolla, important, loco, lowry,
# Average loss at step 62000: 2.833920
# Average loss at step 64000: 2.775356
# Average loss at step 66000: 2.766865
# Average loss at step 68000: 2.716004
# Average loss at step 70000: 2.776581
# Nearest to not: never, always, actually, occasionally, calculate, valentinians, generally, t,
# Nearest to that: which, however, what, mormonism, but, riga, where, csd,
# Nearest to there: they, it, he, we, bats, leclerc, therefore, she,
# Nearest to to: ferris, would, will, might, towards, cannot, should, must,
# Nearest to see: interjections, refers, consider, geometric, include, sasha, irresponsibility, aur,
# Nearest to while: although, though, however, after, before, when, including, but,
# Nearest to as: preterite, cloaca, diocesan, when, bridgehead, eocene, demotic, dimers,
# Nearest to used: known, involved, available, referred, required, found, considered, opposed,
# Nearest to proposed: created, led, stated, explained, fis, proved, crept, anc,
# Nearest to square: allahabad, viterbo, transitional, clarion, quark, freer, veeck, instructional,
# Nearest to freedom: repellent, tetrahedral, enthalpy, classifies, plurals, dx, plywood, bdsm,
# Nearest to heavy: specialty, gautama, kidder, cried, oup, bentheim, naval, medium,
# Nearest to active: unusual, radically, important, collision, venturing, hallstatt, container, ellipsoid,
# Nearest to arts: nasal, art, discounted, flemish, memory, sociology, jewel, tod,
# Nearest to construction: buzzard, majority, ethics, adamant, vital, opulent, board, prophase,
# Nearest to additional: tompkins, embodiment, odd, important, jolla, mol, extensive, lowry,
# Average loss at step 72000: 2.802151
# Average loss at step 74000: 2.656894
# Average loss at step 76000: 2.800594
# Average loss at step 78000: 2.819345
# Average loss at step 80000: 2.784044
# Nearest to not: actually, never, always, t, generally, typically, almost, occasionally,
# Nearest to that: which, however, what, this, mormonism, mixtures, antidisestablishmentarianism, csd,
# Nearest to there: they, it, he, we, she, therefore, bats, kames,
# Nearest to to: ferris, towards, should, will, cannot, might, wondered, escher,
# Nearest to see: include, refers, aur, consider, interjections, sasha, called, references,
# Nearest to while: although, though, after, when, before, however, but, including,
# Nearest to as: preterite, cloaca, when, fiorentina, diocesan, stds, mystics, demotic,
# Nearest to used: known, available, required, referred, involved, opposed, found, seen,
# Nearest to proposed: created, stated, proved, explained, led, fis, crept, kilpatrick,
# Nearest to square: allahabad, viterbo, transitional, clarion, freer, quark, veeck, european,
# Nearest to freedom: repellent, classifies, enthalpy, dx, tetrahedral, plurals, bdsm, plywood,
# Nearest to heavy: specialty, gautama, cried, oup, kidder, bentheim, medium, westerly,
# Nearest to active: unusual, radically, important, hallstatt, open, collision, venturing, ellipsoid,
# Nearest to arts: nasal, art, discounted, flemish, jewel, sociology, memory, tour,
# Nearest to construction: majority, buzzard, ethics, adamant, opulent, vital, scientific, nature,
# Nearest to additional: embodiment, tompkins, odd, extensive, important, jolla, amazing, lowry,
# Average loss at step 82000: 2.673031
# Average loss at step 84000: 2.771421
# Average loss at step 86000: 2.741432
# Average loss at step 88000: 2.756105
# Average loss at step 90000: 2.738901
# Nearest to not: actually, never, always, nothing, occasionally, generally, t, typically,
# Nearest to that: which, however, what, mormonism, riga, antidisestablishmentarianism, this, where,
# Nearest to there: they, it, he, we, she, leclerc, however, probable,
# Nearest to to: ferris, should, might, could, would, must, towards, cannot,
# Nearest to see: include, interjections, consider, but, references, list, sasha, aur,
# Nearest to while: although, though, when, before, after, however, toward, but,
# Nearest to as: preterite, cloaca, meticulous, demotic, yttrium, mystics, when, fiorentina,
# Nearest to used: known, required, available, referred, involved, opposed, seen, responsible,
# Nearest to proposed: created, proved, stated, led, explained, provided, fis, occupied,
# Nearest to square: allahabad, viterbo, clarion, transitional, freer, quark, instructional, veeck,
# Nearest to freedom: classifies, repellent, enthalpy, dx, tetrahedral, plurals, terracotta, satisfying,
# Nearest to heavy: specialty, oup, cried, medium, gautama, consumption, bentheim, fuel,
# Nearest to active: unusual, important, radically, hallstatt, collision, existing, open, venturing,
# Nearest to arts: art, nasal, flemish, sociology, jewel, discounted, memory, resupply,
# Nearest to construction: ethics, buzzard, majority, adamant, opulent, vital, narcotic, sinless,
# Nearest to additional: embodiment, tompkins, odd, extensive, important, jolla, amazing, lowry,
# Average loss at step 92000: 2.694996
# Average loss at step 94000: 2.727084
# Average loss at step 96000: 2.713185
# Average loss at step 98000: 2.379861
# Average loss at step 100000: 2.428903
# Nearest to not: never, actually, always, t, nothing, necessarily, occasionally, generally,
# Nearest to that: which, however, what, antidisestablishmentarianism, mormonism, where, how, shek,
# Nearest to there: they, it, he, we, she, these, therefore, kames,
# Nearest to to: should, ferris, towards, would, might, will, cannot, could,
# Nearest to see: include, consider, interjections, aur, sasha, references, refers, list,
# Nearest to while: although, though, when, before, after, however, but, began,
# Nearest to as: cloaca, preterite, demotic, bridgehead, gaspar, neutralize, idb, mystics,
# Nearest to used: known, required, involved, referred, available, identified, opposed, necessary,
# Nearest to proposed: created, stated, proved, explained, led, fis, provided, crept,
# Nearest to square: viterbo, allahabad, clarion, freer, transitional, quark, borderlands, veeck,
# Nearest to freedom: classifies, repellent, enthalpy, plurals, tetrahedral, dx, terracotta, bdsm,
# Nearest to heavy: specialty, gautama, cried, oup, medium, consumption, ballistic, steady,
# Nearest to active: unusual, important, open, radically, hallstatt, existing, collision, ellipsoid,
# Nearest to arts: art, nasal, sociology, discounted, jewel, flemish, tod, impiety,
# Nearest to construction: buzzard, majority, ethics, adamant, opulent, sinless, development, narcotic,
# Nearest to additional: embodiment, odd, tompkins, important, jolla, extensive, amazing, appropriate,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
