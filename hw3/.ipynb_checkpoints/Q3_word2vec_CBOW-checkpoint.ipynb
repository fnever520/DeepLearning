# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
#from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# ## Downloading Data

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
    print(_)
    print(filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# ## Converting data to a string

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# ## Building the Vocabulary (Dictionaries)

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# ## Generating batches of data
#
# Unlike data in skip-gram, here data is of following sizes
# * batch: [batch_size, context_window size - 1] # words found in the context
# * labels: [batch_size, 1] # target word (word to be predicted)

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index

    span = 2 * skip_window + 1 # [ skip_window target skip_window ]

    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side

    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)

    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself

        # do this num_skips (2 times)
        # do this (1 time)

        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels



for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    
    print('    batch:', [[reverse_dictionary[bii] for bii in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# ## Running Embedding Learning

# %%
num_steps = 100001

if __name__ == '__main__':
    batch_size = 128
    embedding_size = 128 # Dimension of the embedding vector.
    skip_window = 1 # How many words to consider left and right.
    num_skips = 2 # How many times to reuse an input to generate a label.
    # We pick a random validation set to sample nearest neighbors. here we limit the
    # validation samples to the words that have a low numeric ID, which by
    # construction are also the most frequent.
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100 # Only pick dev samples in the head of the distribution.
    # pick 16 samples from 100
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
    num_sampled = 64 # Number of negative examples to sample.

    graph = tf.Graph()

    with graph.as_default(), tf.device('/cpu:0'):

        # Input data.
        train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

        # Variables.
        # embedding, vector for each word in the vocabulary
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
        softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Averaging embeddings accross the full context into a single embedding layer
        context_embeddings = []
        for i in range(2*skip_window):
            context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]))
            
        avg_embed =  tf.reduce_mean(tf.stack(axis=0,values=context_embeddings),0,keep_dims=False)

        # Compute the softmax loss, using a sample of the negative labels each time.
        # inputs are embeddings of the train words
        # with this loss we optimize weights, biases, embeddings

        loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

        # Optimizer.
        optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

        # Compute the similarity between minibatch examples and all embeddings.
        # We use the cosine distance:
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

    with tf.Session(graph=graph) as session:
        tf.global_variables_initializer().run()
        print('Initialized')
        average_loss = 0
        for step in range(num_steps):
            batch_data, batch_labels = generate_batch(batch_size, skip_window)
            feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
            _, l = session.run([optimizer, loss], feed_dict=feed_dict)
            average_loss += l
            if step % 2000 == 0:
                if step > 0:
                    average_loss = average_loss / 2000
                    # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
        final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-8-3160d5537020>:39: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From C:\Users\User\Miniconda3\envs\nlp\lib\site-packages\tensorflow\python\ops\nn_impl.py:1124: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From <ipython-input-8-3160d5537020>:53: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Initialized
# Average loss at step 0: 7.348884
# Nearest to zero: caribbean, mgm, hogeschool, hamsters, lenat, aswan, wcl, documented,
# Nearest to will: french, aediles, latinos, grafton, homeschool, nuclear, sagas, aquilegia,
# Nearest to after: psa, jinshi, skip, branagh, arawak, bancroft, tumbling, mckay,
# Nearest to over: plata, wb, jumped, senex, resolvers, bandit, hernia, kong,
# Nearest to as: gestae, unaided, undergrowth, celibacy, uris, accompaniments, cites, prester,
# Nearest to state: fostering, upload, miko, ivo, sorbonne, archetype, sulphur, ventured,
# Nearest to during: objectively, flywheel, jennie, flagella, precisely, jagger, harmonisation, afternoon,
# Nearest to seven: rotunda, elohim, abundance, individualists, additional, divide, portions, thumbs,
# Nearest to operations: tabulate, karel, crafts, ivoire, ihs, fireball, adjutant, archie,
# Nearest to bill: montaigne, thicknesses, gehrig, marlowe, masjid, npd, bytecode, siouxsie,
# Nearest to scale: boopsie, arcy, irr, survivor, gees, suvs, incited, envoy,
# Nearest to behind: ocaml, wavering, coppersmith, hulls, digital, balkans, unn, domingo,
# Nearest to san: longinus, squarely, mitsuda, instrumentalists, termite, jeane, saltwater, ridley,
# Nearest to derived: healthier, carnahan, renderer, possessive, propagated, willie, riverfront, debian,
# Nearest to mathematics: reunion, preserved, bog, pipers, syntactic, debussy, initiated, election,
# Nearest to pre: oise, rout, guinness, carnap, gangetic, various, dollar, linn,
# Average loss at step 2000: 4.041050
# Average loss at step 4000: 3.510084
# Average loss at step 6000: 3.341983
# Average loss at step 8000: 3.191529
# Average loss at step 10000: 3.147495
# Nearest to zero: eight, nine, five, six, seven, four, three, nuncio,
# Nearest to will: can, would, could, aediles, aquilegia, sylia, must, homeschool,
# Nearest to after: skip, tumbling, as, contentious, bancroft, including, coupled, ribbon,
# Nearest to over: on, plata, iblis, intv, yag, senex, impeachment, heterodox,
# Nearest to as: nu, after, under, goldstein, until, unaided, cites, gestae,
# Nearest to state: within, rodriguez, reuven, upload, sulphur, aerosmith, sorbonne, fostering,
# Nearest to during: at, on, including, in, for, under, where, nonstandard,
# Nearest to seven: nine, eight, six, four, three, five, zero, two,
# Nearest to operations: karel, ivoire, tabulate, crafts, livermore, existent, fireball, adjutant,
# Nearest to bill: montaigne, thicknesses, npd, marlowe, gehrig, nationalisation, masjid, thales,
# Nearest to scale: boopsie, irr, arcy, suvs, gees, survivor, incited, envoy,
# Nearest to behind: wavering, coppersmith, digital, spectrometers, ocaml, cassino, hulls, unn,
# Nearest to san: longinus, squarely, mitsuda, termite, uprooted, jeane, ridley, instrumentalists,
# Nearest to derived: renderer, healthier, propagated, possessive, riverfront, used, varanus, zs,
# Nearest to mathematics: preserved, reunion, pipers, debussy, syntactic, esperanto, election, bog,
# Nearest to pre: guinness, carnap, oise, rout, gangetic, condon, dollar, gos,
# Average loss at step 12000: 3.171654
# Average loss at step 14000: 3.132326
# Average loss at step 16000: 3.148851
# Average loss at step 18000: 3.106299
# Average loss at step 20000: 2.992444
# Nearest to zero: eight, six, nine, seven, five, four, three, auteurs,
# Nearest to will: can, would, could, must, may, might, cannot, should,
# Nearest to after: tumbling, before, skip, until, dropped, sri, audacity, informal,
# Nearest to over: plata, intv, impeachment, yag, heterodox, pears, glace, iblis,
# Nearest to as: unaided, nu, electroacoustic, until, interlinked, sobre, goldstein, fasttrack,
# Nearest to state: aerosmith, rodriguez, reuven, fostering, stephenson, advocates, sulphur, ventured,
# Nearest to during: on, in, at, upon, under, throughout, including, before,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to operations: karel, ivoire, crafts, livermore, existent, tabulate, budo, adjutant,
# Nearest to bill: npd, montaigne, gehrig, marlowe, nationalisation, thicknesses, bytecode, gilmour,
# Nearest to scale: boopsie, irr, suvs, sident, survivor, arcy, directory, gees,
# Nearest to behind: spectrometers, coppersmith, wavering, cassino, digital, behaviour, royston, patchy,
# Nearest to san: squarely, longinus, ridley, mitsuda, uprooted, termite, jeane, discourse,
# Nearest to derived: renderer, propagated, healthier, possessive, riverfront, zs, mateo, toys,
# Nearest to mathematics: preserved, reunion, pipers, esperanto, syntactic, debussy, kleine, bhindranwale,
# Nearest to pre: guinness, gos, condon, carnap, ferdinand, growing, treats, dollar,
# Average loss at step 22000: 3.055466
# Average loss at step 24000: 3.026792
# Average loss at step 26000: 2.993228
# Average loss at step 28000: 3.019284
# Average loss at step 30000: 2.989808
# Nearest to zero: eight, seven, nine, five, four, six, three, auteurs,
# Nearest to will: would, can, could, must, may, might, cannot, should,
# Nearest to after: before, when, until, tumbling, skip, dropped, informal, connectors,
# Nearest to over: impeachment, intv, implants, off, creole, glace, yag, on,
# Nearest to as: nu, unaided, fresnel, today, interlinked, nanking, bidatsu, because,
# Nearest to state: aerosmith, canada, bottles, stephenson, veterans, xia, fostering, reuven,
# Nearest to during: in, at, throughout, on, under, before, upon, where,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to operations: ivoire, karel, livermore, crafts, existent, budo, tabulate, enters,
# Nearest to bill: npd, montaigne, gehrig, marlowe, nationalisation, tf, thicknesses, gilmour,
# Nearest to scale: sident, boopsie, irr, suvs, directory, anomalous, baryons, survivor,
# Nearest to behind: spectrometers, cassino, coppersmith, wavering, digital, patchy, behaviour, royston,
# Nearest to san: squarely, longinus, uprooted, ridley, torrents, termite, mitsuda, jeane,
# Nearest to derived: renderer, healthier, propagated, possessive, zs, away, riverfront, mateo,
# Nearest to mathematics: preserved, pipers, esperanto, reunion, bhindranwale, election, syntactic, debussy,
# Nearest to pre: guinness, growing, gos, condon, carnap, ferdinand, dollar, treats,
# Average loss at step 32000: 2.842171
# Average loss at step 34000: 2.942682
# Average loss at step 36000: 2.942428
# Average loss at step 38000: 2.941084
# Average loss at step 40000: 2.920345
# Nearest to zero: six, eight, five, seven, four, nine, three, two,
# Nearest to will: would, can, could, may, must, might, cannot, should,
# Nearest to after: before, when, until, during, informal, tutoring, tumbling, dropped,
# Nearest to over: off, implants, impeachment, glace, glengarry, sophia, yag, intv,
# Nearest to as: nu, unaided, because, fresnel, interlinked, lehman, oops, sera,
# Nearest to state: canada, aerosmith, city, endpoints, xia, veterans, bottles, array,
# Nearest to during: in, throughout, before, at, when, after, under, gives,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to operations: karel, ivoire, livermore, existent, crafts, enters, limitless, budo,
# Nearest to bill: npd, montaigne, marlowe, gehrig, tf, thicknesses, nationalisation, saintly,
# Nearest to scale: sident, macaroni, boopsie, anomalous, efficiency, suvs, directory, philos,
# Nearest to behind: spectrometers, cassino, through, coppersmith, wavering, gave, patchy, bottled,
# Nearest to san: squarely, ridley, uprooted, torrents, longinus, mysticism, nacional, faithful,
# Nearest to derived: renderer, healthier, away, propagated, removed, possessive, zs, mateo,
# Nearest to mathematics: preserved, pipers, esperanto, bhindranwale, reunion, election, syntactic, lusaka,
# Nearest to pre: guinness, growing, carnap, gos, treats, ferdinand, gangetic, dollar,
# Average loss at step 42000: 2.947352
# Average loss at step 44000: 2.944466
# Average loss at step 46000: 2.905287
# Average loss at step 48000: 2.869528
# Average loss at step 50000: 2.843489
# Nearest to zero: eight, five, seven, six, four, nine, three, two,
# Nearest to will: would, can, could, may, must, cannot, might, should,
# Nearest to after: before, when, during, until, without, informal, while, gave,
# Nearest to over: off, implants, impeachment, out, sophia, glengarry, glace, topped,
# Nearest to as: nu, fresnel, unaided, bidatsu, interlinked, goldstein, sobre, sera,
# Nearest to state: canada, aerosmith, city, xia, endpoints, department, veterans, archetype,
# Nearest to during: in, throughout, before, at, when, after, until, gives,
# Nearest to seven: eight, nine, six, five, four, three, zero, two,
# Nearest to operations: karel, livermore, ivoire, crafts, liberties, enters, existent, budo,
# Nearest to bill: npd, montaigne, marlowe, tf, gehrig, thicknesses, saintly, nationalisation,
# Nearest to scale: sident, efficiency, dharmas, cheryl, anomalous, directory, macaroni, baryons,
# Nearest to behind: spectrometers, chills, cassino, bottled, coppersmith, gave, kashmir, through,
# Nearest to san: squarely, ridley, uprooted, torrents, longinus, mysticism, wickets, harris,
# Nearest to derived: renderer, removed, away, healthier, mateo, propagated, zs, possessive,
# Nearest to mathematics: pipers, preserved, esperanto, bhindranwale, cameroun, mise, kleine, lusaka,
# Nearest to pre: growing, guinness, carnap, gos, treats, gangetic, ferdinand, condon,
# Average loss at step 52000: 2.883401
# Average loss at step 54000: 2.861104
# Average loss at step 56000: 2.853372
# Average loss at step 58000: 2.760158
# Average loss at step 60000: 2.827105
# Nearest to zero: five, seven, six, nine, four, eight, three, two,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to after: before, when, during, until, without, informal, gave, while,
# Nearest to over: off, implants, sophia, coups, glengarry, topped, impeachment, microscopy,
# Nearest to as: nu, interlinked, electroacoustic, because, fresnel, bidatsu, malevolent, lehman,
# Nearest to state: xia, aerosmith, states, canada, department, city, advocates, endpoints,
# Nearest to during: in, before, when, after, at, throughout, within, until,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to operations: karel, livermore, ivoire, liberties, crafts, existent, budo, enters,
# Nearest to bill: npd, montaigne, tf, marlowe, gehrig, saintly, thicknesses, gba,
# Nearest to scale: sident, efficiency, amounts, cheryl, anomalous, dharmas, irreversible, directory,
# Nearest to behind: spectrometers, through, chills, before, cassino, kashmir, coppersmith, gave,
# Nearest to san: squarely, ridley, uprooted, torrents, mysticism, harris, castile, hungary,
# Nearest to derived: renderer, removed, away, healthier, mateo, zs, possessive, propagated,
# Nearest to mathematics: preserved, esperanto, bhindranwale, cameroun, pipers, kleine, mise, regains,
# Nearest to pre: growing, guinness, carnap, treats, ferdinand, gos, gangetic, condon,
# Average loss at step 62000: 2.833991
# Average loss at step 64000: 2.778256
# Average loss at step 66000: 2.771057
# Average loss at step 68000: 2.717945
# Average loss at step 70000: 2.768490
# Nearest to zero: five, eight, seven, six, nine, four, three, two,
# Nearest to will: would, can, could, must, may, should, cannot, might,
# Nearest to after: before, when, during, without, until, informal, afterwards, while,
# Nearest to over: off, implants, sophia, glengarry, fa, impeachment, inexplicable, topped,
# Nearest to as: nu, malevolent, electroacoustic, interlinked, because, lehman, when, incarnations,
# Nearest to state: xia, aerosmith, city, states, endpoints, department, stephenson, veterans,
# Nearest to during: in, before, throughout, after, when, under, at, until,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to operations: livermore, karel, systems, ivoire, liberties, budo, enters, crafts,
# Nearest to bill: npd, montaigne, tf, marlowe, saintly, gehrig, thicknesses, gba,
# Nearest to scale: sident, efficiency, amounts, dharmas, irreversible, cheryl, weight, box,
# Nearest to behind: through, chills, spectrometers, bottled, before, gave, beyond, until,
# Nearest to san: squarely, torrents, ridley, uprooted, castile, mysticism, wickets, faithful,
# Nearest to derived: removed, renderer, away, healthier, mateo, possessive, zs, propagated,
# Nearest to mathematics: esperanto, cameroun, preserved, bhindranwale, pipers, mise, kleine, syntactic,
# Nearest to pre: growing, carnap, guinness, treats, gos, prosaic, gangetic, turbofans,
# Average loss at step 72000: 2.795283
# Average loss at step 74000: 2.656272
# Average loss at step 76000: 2.803306
# Average loss at step 78000: 2.822407
# Average loss at step 80000: 2.781870
# Nearest to zero: seven, five, six, eight, four, nine, three, two,
# Nearest to will: would, can, could, must, may, should, cannot, might,
# Nearest to after: before, when, during, without, although, informal, for, until,
# Nearest to over: off, implants, impeachment, glengarry, inexplicable, across, sophia, topped,
# Nearest to as: interlinked, nu, electroacoustic, malevolent, locality, when, lehman, unaided,
# Nearest to state: aerosmith, states, xia, city, veterans, endpoints, department, archetype,
# Nearest to during: in, after, before, throughout, when, at, although, until,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to operations: livermore, systems, karel, ivoire, liberties, enters, budo, crafts,
# Nearest to bill: npd, montaigne, marlowe, tf, gehrig, saintly, henry, thicknesses,
# Nearest to scale: sident, amounts, efficiency, dharmas, cheryl, anomalous, ventricles, proportion,
# Nearest to behind: through, before, chills, spectrometers, beyond, bottled, coppersmith, on,
# Nearest to san: squarely, torrents, ridley, castile, uprooted, wickets, faithful, mysticism,
# Nearest to derived: removed, renderer, away, healthier, possessive, mateo, zs, apart,
# Nearest to mathematics: esperanto, cameroun, pipers, preserved, mise, bhindranwale, syntactic, hotel,
# Nearest to pre: growing, carnap, treats, guinness, prosaic, sayfawa, gos, gangetic,
# Average loss at step 82000: 2.675286
# Average loss at step 84000: 2.775053
# Average loss at step 86000: 2.746777
# Average loss at step 88000: 2.758577
# Average loss at step 90000: 2.742006
# Nearest to zero: seven, five, six, eight, four, nine, three, million,
# Nearest to will: would, can, could, must, may, might, should, cannot,
# Nearest to after: before, during, when, without, afterwards, despite, informal, although,
# Nearest to over: off, across, implants, around, out, inexplicable, sophia, about,
# Nearest to as: nu, electroacoustic, interlinked, fresnel, malevolent, lehman, unaided, slowdown,
# Nearest to state: city, aerosmith, states, xia, phenomenon, archetype, national, endpoints,
# Nearest to during: in, after, before, throughout, when, although, within, until,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to operations: livermore, systems, ivoire, liberties, karel, roads, budo, enters,
# Nearest to bill: npd, montaigne, marlowe, tf, carmack, gehrig, saintly, calatrava,
# Nearest to scale: sident, dharmas, amounts, efficiency, proportion, weight, ventricles, charted,
# Nearest to behind: through, chills, spectrometers, before, bottled, coppersmith, beyond, back,
# Nearest to san: squarely, torrents, castile, ridley, uprooted, wickets, faithful, mysticism,
# Nearest to derived: removed, renderer, apart, away, possessive, borrowed, separated, mateo,
# Nearest to mathematics: esperanto, cameroun, syntactic, learners, hotel, pipers, scholarship, education,
# Nearest to pre: carnap, growing, guinness, treats, gangetic, sayfawa, repressed, prosaic,
# Average loss at step 92000: 2.687223
# Average loss at step 94000: 2.722837
# Average loss at step 96000: 2.711191
# Average loss at step 98000: 2.382203
# Average loss at step 100000: 2.417023
# Nearest to zero: five, six, seven, eight, four, nine, three, two,
# Nearest to will: would, can, could, must, should, might, may, cannot,
# Nearest to after: before, when, during, without, despite, afterwards, for, informal,
# Nearest to over: off, around, across, implants, inexplicable, resolvers, rigidly, ofdm,
# Nearest to as: interlinked, electroacoustic, nu, malevolent, goldstein, lehman, fresnel, psalter,
# Nearest to state: states, aerosmith, city, xia, veterans, deletions, government, department,
# Nearest to during: in, after, before, throughout, at, when, within, under,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to operations: livermore, systems, liberties, ivoire, karel, roads, budo, crafts,
# Nearest to bill: npd, montaigne, marlowe, tf, saintly, gehrig, carmack, henry,
# Nearest to scale: sident, amounts, dharmas, proportion, efficiency, weight, box, ventricles,
# Nearest to behind: through, chills, spectrometers, before, beyond, coppersmith, bottled, back,
# Nearest to san: squarely, torrents, castile, uprooted, ridley, wickets, faithful, beggars,
# Nearest to derived: removed, apart, renderer, away, borrowed, derives, separate, separated,
# Nearest to mathematics: esperanto, cameroun, hotel, syntactic, pipers, linguistics, scholarship, learners,
# Nearest to pre: growing, carnap, guinness, treats, sayfawa, repressed, gangetic, turbofans,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
