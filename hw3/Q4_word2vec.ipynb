# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
#from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
num_skips = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.930999
# Nearest to eight: capacities, compose, hyatt, acquainted, revised, accessing, leaks, fichte,
# Nearest to than: arrests, worsening, exaggeration, bolsheviks, arabica, ragtime, depressing, immortal,
# Nearest to however: qur, keith, resolve, cures, relinquished, punitive, ian, cursor,
# Nearest to called: deflected, ben, millennia, outburst, pain, brick, amputated, replies,
# Nearest to seven: parasites, related, access, kipsigis, haiti, horst, capella, shelved,
# Nearest to were: cube, cathar, hawthorn, avenged, yachts, ucs, stalks, yuga,
# Nearest to known: ghent, fsm, interdiction, muscat, abdallah, bean, hyksos, dashing,
# Nearest to into: blas, toku, fung, reorganised, bequeathed, kwanzaa, pseudoscientific, bank,
# Nearest to so: unavailable, mahjong, lauter, illegal, sufi, proxima, amplifies, symbols,
# Nearest to d: hyperactivity, rsa, traceable, firewall, motorway, demoralized, lorenzo, sultan,
# Nearest to no: firmus, solemnity, railway, aclu, novello, fingal, lup, honours,
# Nearest to was: hooded, adrienne, marinus, biotechnology, ova, aphorism, quatre, stint,
# Nearest to or: technician, finnish, seventeenth, zetalisp, submersible, bolivar, prevailed, girlfriends,
# Nearest to is: rovers, kelley, fief, amiable, why, proximal, anic, iranians,
# Nearest to be: spare, cater, gayle, tails, fabien, pants, matches, dutchman,
# Nearest to which: salesman, unclaimed, francisco, ves, scenarios, generals, petitions, lured,
# Average loss at step 2000: 4.506945
# Average loss at step 4000: 4.119311
# Average loss at step 6000: 3.923223
# Average loss at step 8000: 3.921968
# Average loss at step 10000: 3.888653
# Nearest to eight: seven, nine, six, five, four, zero, three, one,
# Nearest to than: ragtime, diffeomorphic, arabica, herbivores, symbolize, renders, emulsions, worsening,
# Nearest to however: context, russian, principle, nevi, tuesday, relinquished, discourse, ona,
# Nearest to called: millennia, replies, deflected, peaks, gave, amputated, pain, infamously,
# Nearest to seven: eight, six, nine, zero, five, three, four, one,
# Nearest to were: are, keene, ethno, reopening, was, hawthorn, mummy, regains,
# Nearest to known: ghent, huddle, memex, talk, participant, interdiction, zeal, dashing,
# Nearest to into: toku, blas, pseudoscientific, menial, tld, hidalgo, hundred, adi,
# Nearest to so: illegal, unavailable, ganges, stringing, cristobal, backfield, represent, until,
# Nearest to d: motorway, demoralized, sultan, s, rsa, succumbing, unconditional, reconnaissance,
# Nearest to no: schools, automatically, bower, eac, sentient, derived, honours, firmus,
# Nearest to was: is, intuitionism, afer, struggles, bracewell, stamens, shaped, were,
# Nearest to or: equinox, ningen, radar, zooplankton, hildesheim, whirlpool, spiegel, and,
# Nearest to is: was, are, be, twentieth, dedications, rovers, lazarus, or,
# Nearest to be: microlensing, shrines, is, have, taya, blotter, assaulted, bahama,
# Nearest to which: scenarios, continuity, flames, brennan, enforcement, excitotoxins, bridge, misc,
# Average loss at step 12000: 3.866960
# Average loss at step 14000: 3.835390
# Average loss at step 16000: 3.741108
# Average loss at step 18000: 3.817708
# Average loss at step 20000: 3.797676
# Nearest to eight: seven, five, three, six, nine, four, zero, two,
# Nearest to than: renders, symbolize, conceptions, maidstone, gardens, rainbow, or, gyatso,
# Nearest to however: although, also, collapsed, loosened, context, provisions, deviations, nor,
# Nearest to called: deflected, infamously, crucifixes, millennia, replies, selwyn, peaks, sweeping,
# Nearest to seven: eight, five, six, three, four, nine, zero, two,
# Nearest to were: are, was, have, keene, many, nva, had, specifically,
# Nearest to known: zeal, huddle, jockeys, ghent, participant, freeway, organisations, materiality,
# Nearest to into: dimona, blas, menial, toku, varese, sukarno, tld, adi,
# Nearest to so: apples, retaliate, backfield, represent, illegal, unavailable, mere, licensee,
# Nearest to d: b, UNK, motorway, haredi, succumbing, demoralized, one, handfasting,
# Nearest to no: bower, employ, bothnian, automatically, sol, realaudio, xm, schools,
# Nearest to was: is, were, had, be, has, ayman, been, are,
# Nearest to or: and, initialized, presbyterianism, ningen, milano, burma, middleweight, rice,
# Nearest to is: was, are, has, be, emigr, royal, doesn, discriminated,
# Nearest to be: have, microlensing, was, worldcom, is, are, adjective, assaulted,
# Nearest to which: that, this, it, insulating, pearls, simulated, pcs, dislike,
# Average loss at step 22000: 3.725281
# Average loss at step 24000: 3.795365
# Average loss at step 26000: 3.639210
# Average loss at step 28000: 3.587880
# Average loss at step 30000: 3.633102
# Nearest to eight: seven, six, nine, five, three, four, zero, one,
# Nearest to than: renders, or, conceptions, symbolize, nicolai, maidstone, arrests, cheated,
# Nearest to however: although, but, also, since, loosened, deviations, collapsed, ona,
# Nearest to called: infamously, deflected, millennia, selwyn, crucifixes, when, mere, unambiguous,
# Nearest to seven: eight, six, five, three, four, zero, nine, two,
# Nearest to were: are, was, is, had, miniseries, be, been, keene,
# Nearest to known: regarded, well, used, zeal, jockeys, organisations, errands, such,
# Nearest to into: from, dimona, menial, to, blas, toku, varese, bequeathed,
# Nearest to so: maneuverable, reese, apples, infecting, mere, continuous, utah, ashoka,
# Nearest to d: b, underpinnings, josephine, haredi, unorganized, mercator, succumbing, gadamer,
# Nearest to no: bower, xm, integrating, filled, realaudio, falsifiability, ascendancy, employ,
# Nearest to was: is, were, had, became, being, be, has, yelled,
# Nearest to or: brahmaputra, and, than, harmon, chanted, hinckley, png, spanning,
# Nearest to is: was, are, has, were, be, siberia, rebbe, arameans,
# Nearest to be: have, been, was, microlensing, were, is, him, blotter,
# Nearest to which: that, where, this, also, it, simulated, pauper, forms,
# Average loss at step 32000: 3.666206
# Average loss at step 34000: 3.751354
# Average loss at step 36000: 3.687382
# Average loss at step 38000: 3.718728
# Average loss at step 40000: 3.677525
# Nearest to eight: six, seven, four, five, nine, zero, two, three,
# Nearest to than: or, suffragan, renders, sp, texaco, conceptions, greyhound, managers,
# Nearest to however: although, but, if, not, that, since, when, because,
# Nearest to called: infamously, deflected, crucifixes, millennia, selwyn, iraqis, lard, sweeping,
# Nearest to seven: six, eight, four, five, nine, one, three, zero,
# Nearest to were: are, was, be, many, miniseries, been, had, have,
# Nearest to known: well, regarded, used, such, zeal, errands, evaluate, dashing,
# Nearest to into: from, dimona, windshield, menial, in, blas, clones, down,
# Nearest to so: ashoka, credibility, if, reese, maneuverable, baritone, it, licensee,
# Nearest to d: b, underpinnings, fairfield, mercator, demoralized, motorway, headache, josephine,
# Nearest to no: any, however, a, that, bower, integrating, realaudio, falsifiability,
# Nearest to was: is, were, be, being, had, has, means, lameness,
# Nearest to or: and, than, with, silverberg, chicken, inhabit, attackers, plight,
# Nearest to is: was, are, has, appeals, being, be, were, means,
# Nearest to be: have, being, was, been, were, unitarian, refer, are,
# Nearest to which: that, where, it, this, also, but, still, not,
# Average loss at step 42000: 3.676166
# Average loss at step 44000: 3.707432
# Average loss at step 46000: 3.669754
# Average loss at step 48000: 3.755197
# Average loss at step 50000: 3.654717
# Nearest to eight: seven, nine, six, four, five, one, three, zero,
# Nearest to than: greyhound, suffragan, sp, renders, texaco, conceptions, powerful, more,
# Nearest to however: although, but, not, because, since, when, that, while,
# Nearest to called: infamously, iraqis, selwyn, crucifixes, balkh, considered, heading, named,
# Nearest to seven: six, eight, four, five, nine, three, one, two,
# Nearest to were: are, was, had, miniseries, keene, being, doohan, prosecutors,
# Nearest to known: well, regarded, such, seen, used, mindstorms, zeal, errands,
# Nearest to into: from, windshield, dimona, to, in, bequeathed, menial, blas,
# Nearest to so: credibility, maneuverable, ashoka, reese, licensee, baritone, infecting, not,
# Nearest to d: b, underpinnings, mercator, fairfield, rearrange, patanjali, escher, one,
# Nearest to no: any, only, if, ascendancy, not, millay, integrating, automatically,
# Nearest to was: is, were, had, being, became, are, be, has,
# Nearest to or: and, without, fittest, idris, conservatorium, selectively, hailie, scripting,
# Nearest to is: was, are, be, has, appeals, became, prone, being,
# Nearest to be: have, is, being, was, refer, are, been, mishnaic,
# Nearest to which: that, where, when, this, but, and, who, signet,
# Average loss at step 52000: 3.668818
# Average loss at step 54000: 3.760807
# Average loss at step 56000: 3.731006
# Average loss at step 58000: 3.665972
# Average loss at step 60000: 3.721404
# Nearest to eight: seven, six, four, nine, five, three, one, zero,
# Nearest to than: powerful, much, more, suffragan, greyhound, but, fernando, sp,
# Nearest to however: although, but, while, that, because, when, also, breastplate,
# Nearest to called: infamously, selwyn, iraqis, considered, lard, crucifixes, uncertainties, envy,
# Nearest to seven: eight, five, six, nine, four, three, one, zero,
# Nearest to were: are, was, be, have, had, been, many, being,
# Nearest to known: regarded, well, seen, used, zeal, referred, such, errands,
# Nearest to into: from, dimona, windshield, varese, through, down, superiority, along,
# Nearest to so: credibility, not, licensee, maneuverable, numbered, utah, reese, baritone,
# Nearest to d: b, underpinnings, mercator, lecture, blair, muds, fairfield, galesburg,
# Nearest to no: any, a, integrating, millay, if, eprint, ascendancy, dct,
# Nearest to was: is, were, became, being, had, has, are, cyclopaedia,
# Nearest to or: and, like, without, forster, with, mandrakesoft, thc, for,
# Nearest to is: was, are, has, became, be, becomes, contains, were,
# Nearest to be: have, been, were, being, refer, are, antonov, neglecting,
# Nearest to which: that, where, when, although, this, still, who, also,
# Average loss at step 62000: 3.694559
# Average loss at step 64000: 3.718347
# Average loss at step 66000: 3.530439
# Average loss at step 68000: 3.489980
# Average loss at step 70000: 3.696843
# Nearest to eight: six, nine, seven, four, three, five, zero, one,
# Nearest to than: greyhound, or, sturgis, suffragan, talib, monsoon, toward, much,
# Nearest to however: although, but, while, when, because, and, breastplate, that,
# Nearest to called: selwyn, infamously, iraqis, considered, used, there, known, lard,
# Nearest to seven: eight, six, three, nine, four, five, zero, one,
# Nearest to were: are, was, being, many, be, have, sue, all,
# Nearest to known: regarded, well, used, referred, seen, such, scrap, safl,
# Nearest to into: from, dimona, on, through, windshield, down, retailing, within,
# Nearest to so: if, credibility, ashoka, reese, even, licensee, raya, they,
# Nearest to d: b, underpinnings, mercator, blair, j, sanford, enthusiast, rearrange,
# Nearest to no: any, only, if, not, prefers, a, millay, dct,
# Nearest to was: is, were, had, being, became, has, be, been,
# Nearest to or: and, oscillating, toward, varela, with, idris, for, than,
# Nearest to is: was, became, are, has, be, cyclopaedia, for, can,
# Nearest to be: have, was, refer, been, are, being, were, is,
# Nearest to which: that, where, this, who, and, when, also, but,
# Average loss at step 72000: 3.606054
# Average loss at step 74000: 3.696219
# Average loss at step 76000: 3.609192
# Average loss at step 78000: 3.726509
# Average loss at step 80000: 3.648555
# Nearest to eight: seven, six, nine, five, four, zero, three, one,
# Nearest to than: or, much, greyhound, toward, excretion, monsoon, heller, more,
# Nearest to however: although, but, while, still, when, that, though, because,
# Nearest to called: infamously, iraqis, considered, selwyn, known, where, orientalis, diminishes,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to were: are, was, being, had, have, became, many, be,
# Nearest to known: regarded, used, well, referred, seen, described, such, discovering,
# Nearest to into: through, from, dimona, near, windshield, down, varese, rename,
# Nearest to so: even, reese, ashoka, credibility, raya, noted, licensee, mede,
# Nearest to d: b, underpinnings, mercator, f, e, r, am, j,
# Nearest to no: any, a, another, millay, little, only, not, dct,
# Nearest to was: is, were, had, became, has, uncontrollably, being, are,
# Nearest to or: than, and, conservatorium, like, lace, without, spires, punched,
# Nearest to is: was, are, has, became, contains, means, gonzalez, be,
# Nearest to be: have, been, being, refer, are, were, ecclesiae, emergent,
# Nearest to which: that, also, this, where, but, it, when, what,
# Average loss at step 82000: 3.691379
# Average loss at step 84000: 3.639691
# Average loss at step 86000: 3.632150
# Average loss at step 88000: 3.575162
# Average loss at step 90000: 3.585284
# Nearest to eight: seven, six, four, five, nine, three, zero, one,
# Nearest to than: or, much, but, like, greyhound, even, articulations, suffragan,
# Nearest to however: although, but, while, that, when, still, because, though,
# Nearest to called: known, infamously, iraqis, selwyn, considered, belatedly, where, lard,
# Nearest to seven: eight, six, four, three, nine, five, one, zero,
# Nearest to were: are, was, had, have, been, being, is, be,
# Nearest to known: regarded, well, used, referred, seen, described, considered, such,
# Nearest to into: through, from, bequeathed, windshield, down, russcol, within, along,
# Nearest to so: if, not, before, thus, menlo, raya, gd, credibility,
# Nearest to d: b, j, UNK, underpinnings, f, r, ferguson, n,
# Nearest to no: any, if, percival, millay, little, another, still, tremolo,
# Nearest to was: is, were, became, has, had, been, being, be,
# Nearest to or: than, and, like, including, but, furlongs, spires, lace,
# Nearest to is: was, are, contains, has, be, became, were, means,
# Nearest to be: being, have, been, refer, is, were, was, cause,
# Nearest to which: this, that, where, also, but, what, however, who,
# Average loss at step 92000: 3.661492
# Average loss at step 94000: 3.682108
# Average loss at step 96000: 3.636867
# Average loss at step 98000: 3.708767
# Average loss at step 100000: 3.666887
# Nearest to eight: seven, six, nine, four, five, three, zero, one,
# Nearest to than: much, or, articulations, powerful, greyhound, fet, fluctuation, less,
# Nearest to however: although, while, but, when, though, that, because, until,
# Nearest to called: infamously, known, iraqis, belatedly, see, named, emanation, considered,
# Nearest to seven: eight, six, four, five, nine, three, zero, one,
# Nearest to were: are, was, have, had, been, being, miniseries, doohan,
# Nearest to known: regarded, referred, well, used, seen, described, such, considered,
# Nearest to into: through, from, within, russcol, windshield, varese, along, dimona,
# Nearest to so: if, reese, backer, not, mede, ashoka, sometimes, credibility,
# Nearest to d: b, f, underpinnings, c, mercator, j, millimetres, n,
# Nearest to no: any, little, mammuthus, percival, a, another, millay, not,
# Nearest to was: is, were, had, became, been, has, being, are,
# Nearest to or: and, than, enzo, bam, cytosine, whitacre, dreamland, psychosis,
# Nearest to is: was, are, became, has, contains, being, uncontrollably, be,
# Nearest to be: been, being, antonov, refer, are, have, fabien, cause,
# Nearest to which: that, this, where, also, when, what, but, although,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
